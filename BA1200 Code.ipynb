# %% [markdown]
# ## Global Inequalities In Life Expectancy

# %% [markdown]
# #### The dataset has been obtained from Kaggle. Link: https://www.kaggle.com/datasets/nailasrivastava/life-expectancy-analysis/data

# %% [markdown]
# ### 1. Data Exploration

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings("ignore")

# %%
# Loading Dataset
dataset = r"C:\Users\xxxro\OneDrive\Desktop\Data Visualisation Individual Coursework\Life Expectancy Dataset.csv"
life_expectancy_df = pd.read_csv(dataset)

life_expectancy_df
# Out:
#           Country  Year      Status  Life expectancy   Adult Mortality  \
# 0     Afghanistan  2015  Developing              65.0            263.0
# 1     Afghanistan  2014  Developing              59.9            271.0
# 2     Afghanistan  2013  Developing              59.9            268.0
# 3     Afghanistan  2012  Developing              59.5            272.0
# 4     Afghanistan  2011  Developing              59.2            275.0
# ...           ...   ...         ...               ...              ...
# 2933     Zimbabwe  2004  Developing              44.3            723.0
# 2934     Zimbabwe  2003  Developing              44.5            715.0
# 2935     Zimbabwe  2002  Developing              44.8             73.0
# 2936     Zimbabwe  2001  Developing              45.3            686.0
# 2937     Zimbabwe  2000  Developing              46.0            665.0
#
#       infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   \
# ...

# %%
# Checking Dtypes
life_expectancy_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2938 entries, 0 to 2937
# Data columns (total 22 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Country                          2938 non-null   object
#  1   Year                             2938 non-null   int64
#  2   Status                           2938 non-null   object
#  3   Life expectancy                  2928 non-null   float64
#  4   Adult Mortality                  2928 non-null   float64
#  5   infant deaths                    2938 non-null   int64
#  6   Alcohol                          2744 non-null   float64
#  7   percentage expenditure           2938 non-null   float64
#  8   Hepatitis B                      2385 non-null   float64
#  9   Measles                          2938 non-null   int64
#  10   BMI                             2904 non-null   float64
#  11  under-five deaths                2938 non-null   int64
# ...

# %% [markdown]
# ## 2. Data Wrangling

# %%
# Checking for duplicate rows 
duplicates = life_expectancy_df.duplicated()
total_duplicates = duplicates.sum()

print('Number of duplicate rows in the dataset:', total_duplicates)
# Out:
# Number of duplicate rows in the dataset: 0

# %%
# Checking for negative values
negatives = (life_expectancy_df.select_dtypes(include = 'number') < 0).sum().sum()

print('Sum of negative values in the dataset:', negatives)
# Out:
# Sum of negative values in the dataset: 0

# %%
# Checking unique values 
life_expectancy_df.nunique()
# Out:
# Country                             193
# Year                                 16
# Status                                2
# Life expectancy                     362
# Adult Mortality                     425
# infant deaths                       209
# Alcohol                            1076
# percentage expenditure             2328
# Hepatitis B                          87
# Measles                             958
#  BMI                                608
# under-five deaths                   252
# Polio                                73
# Total expenditure                   818
# Diphtheria                           81
#  HIV/AIDS                           200
# GDP                                2490
# Population                         2278
#  thinness  1-19 years               200
#  thinness 5-9 years                 207
# Income composition of resources     625
# Schooling                           173
# dtype: int64

# %%
# Checking for missing values
missing_values = life_expectancy_df.isnull().sum()

missing_values
# Out:
# Country                              0
# Year                                 0
# Status                               0
# Life expectancy                     10
# Adult Mortality                     10
# infant deaths                        0
# Alcohol                            194
# percentage expenditure               0
# Hepatitis B                        553
# Measles                              0
#  BMI                                34
# under-five deaths                    0
# Polio                               19
# Total expenditure                  226
# Diphtheria                          19
#  HIV/AIDS                            0
# GDP                                448
# Population                         652
#  thinness  1-19 years               34
#  thinness 5-9 years                 34
# Income composition of resources    167
# Schooling                          163
# dtype: int64

# %%
# Percentages of missing values
missing_percentage = life_expectancy_df.isnull().mean() * 100

missing_percentage
# Out:
# Country                             0.000000
# Year                                0.000000
# Status                              0.000000
# Life expectancy                     0.340368
# Adult Mortality                     0.340368
# infant deaths                       0.000000
# Alcohol                             6.603131
# percentage expenditure              0.000000
# Hepatitis B                        18.822328
# Measles                             0.000000
#  BMI                                1.157250
# under-five deaths                   0.000000
# Polio                               0.646698
# Total expenditure                   7.692308
# Diphtheria                          0.646698
#  HIV/AIDS                           0.000000
# GDP                                15.248468
# Population                         22.191967
#  thinness  1-19 years               1.157250
#  thinness 5-9 years                 1.157250
# Income composition of resources     5.684139
# ...

# %%
# Imputing median 
columns = ['Alcohol',
           'Hepatitis B',
           'Total expenditure',
           'GDP', 
           'Population',
           'Income composition of resources', 
           'Schooling', 
           ' BMI ',
          'Life expectancy ',
           'Adult Mortality',  
           'Polio', 
           'Diphtheria '] 

life_expectancy_df.loc[:,columns] = life_expectancy_df.loc[:,columns].fillna(life_expectancy_df[columns].median())

# %%
# Dropping Columns 
life_expectancy_df.drop(columns=[' thinness  1-19 years', ' thinness 5-9 years'], inplace=True)

# %%
#Checking if missing values were removed
clean_df = life_expectancy_df.isnull().sum()
clean_df
# Out:
# Country                            0
# Year                               0
# Status                             0
# Life expectancy                    0
# Adult Mortality                    0
# infant deaths                      0
# Alcohol                            0
# percentage expenditure             0
# Hepatitis B                        0
# Measles                            0
#  BMI                               0
# under-five deaths                  0
# Polio                              0
# Total expenditure                  0
# Diphtheria                         0
#  HIV/AIDS                          0
# GDP                                0
# Population                         0
# Income composition of resources    0
# Schooling                          0
# dtype: int64

# %%
# Generating Descriptive Statistics
life_expectancy_df.describe()
# Out:
#               Year  Life expectancy   Adult Mortality  infant deaths  \
# count  2938.000000       2938.000000      2938.000000    2938.000000
# mean   2007.518720         69.234717       164.725664      30.303948
# std       4.613841          9.509115       124.086215     117.926501
# min    2000.000000         36.300000         1.000000       0.000000
# 25%    2004.000000         63.200000        74.000000       0.000000
# 50%    2008.000000         72.100000       144.000000       3.000000
# 75%    2012.000000         75.600000       227.000000      22.000000
# max    2015.000000         89.000000       723.000000    1800.000000
#
#            Alcohol  percentage expenditure  Hepatitis B       Measles   \
# count  2938.000000             2938.000000  2938.000000    2938.000000
# mean      4.546875              738.251295    83.022124    2419.592240
# std       3.921946             1987.914858    22.996984   11467.272489
# ...

# %%
# Exporting Cleaned Dataset
life_expectancy_df.to_excel('Final_Cleaned_df.xlsx', index= False)

# %% [markdown]
# ### 3. Visualisation

# %%
corr = life_expectancy_df[['Life expectancy ', # Selecting variables for heatmap
    'GDP',
    'Schooling',
    'Total expenditure',
    'infant deaths',
    'Adult Mortality',
    ' BMI ']].corr(method='pearson')

# Generating a heatmap
plt.figure(figsize=(8,6))
sns.heatmap(
    corr,
    annot=True,       
    cmap="coolwarm",   
    fmt=".2f",         
    linewidths=0.5
)

plt.title("Education and Mortality Are the Strongest Drivers of Life Expectancy, with Opposing Effects")
plt.tight_layout()
plt.savefig('Heatmap.png')
plt.show()
